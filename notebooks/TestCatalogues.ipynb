# %% [markdown]
# # Test Catalogues

# %%
import xscen as xs
import pandas as pd
from pathlib import Path

cat_file = '/baril/scenario/catalogues/MRCC5-CMIP6.json'
# cat_file = '/tank/cmccray/validation/catalogs/mrcc5-validation-sommaire.json'
pcat = xs.ProjectCatalog(cat_file)
#pcat.df[pcat.df["activity"] == "CMIP"]
# with pd.option_context('display.max_rows', None, 'display.max_columns', None, 'display.max_colwidth', None):
    # pcat.df #[['member', 'driving_member', 'path']]
pcat.df
# Out:
#         date_start                                  variable code frequency  \
# 0              NaT                              (areacella,)  cak        fx
# 1       1960-03-01                           (baresoilFrac,)  cak        se
# 2       1977-11-01                           (baresoilFrac,)  cak        se
# 3       1996-04-01                           (baresoilFrac,)  cak        se
# 4       1997-09-01                           (baresoilFrac,)  cak        se
# ...            ...                                       ...  ...       ...
# 3472866 2063-08-01  (zmla_max, zmla_min, zmla_moy, zmla_std)  cet        sm
# 3472867 2048-11-01  (zmla_max, zmla_min, zmla_moy, zmla_std)  cet        sm
# 3472868 2062-05-01  (zmla_max, zmla_min, zmla_moy, zmla_std)  cet        sm
# 3472869 2083-10-01  (zmla_max, zmla_min, zmla_moy, zmla_std)  cet        sm
# 3472870 2094-02-01  (zmla_max, zmla_min, zmla_moy, zmla_std)  cet        sm
#
#                                                       path format  \
# 0        /tank/climato/arch/cak/invariants/areacella_ca...     nc
# 1        /tank/climato/arch/cak/series/196003/baresoilF...     nc
# 2        /tank/climato/arch/cak/series/197711/baresoilF...     nc
# 3        /tank/climato/arch/cak/series/199604/baresoilF...     nc
# 4        /tank/climato/arch/cak/series/199709/baresoilF...     nc
# ...                                                    ...    ...
# 3472866  /graal/climato/arch/cet/statmens/206308/zmla_c...     nc
# 3472867  /graal/climato/arch/cet/statmens/204811/zmla_c...     nc
# 3472868  /graal/climato/arch/cet/statmens/206205/zmla_c...     nc
# 3472869  /graal/climato/arch/cet/statmens/208310/zmla_c...     nc
# 3472870  /graal/climato/arch/cet/statmens/209402/zmla_c...     nc
#
#                    date_end xrfreq        type processing_level  ...  \
# 0                       NaT     fx  simulation              raw  ...
# 1       1960-03-31 23:59:59     3h  simulation              raw  ...
# 2       1977-11-30 23:59:59     3h  simulation              raw  ...
# 3       1996-04-30 23:59:59     3h  simulation              raw  ...
# 4       1997-09-30 23:59:59     3h  simulation              raw  ...
# ...                     ...    ...         ...              ...  ...
# 3472866 2063-08-31 23:59:59         simulation              raw  ...
# 3472867 2048-11-30 23:59:59         simulation              raw  ...
# 3472868 2062-05-31 23:59:59         simulation              raw  ...
# 3472869 2083-10-31 23:59:59         simulation              raw  ...
# 3472870 2094-02-28 23:59:59         simulation              raw  ...
#
#         driving_model driving_member  experiment member mip_era responsable  \
# 0             CanESM5       r1i1p2f1  historical     r1   CMIP6      Michel
# 1             CanESM5       r1i1p2f1  historical     r1   CMIP6      Michel
# 2             CanESM5       r1i1p2f1  historical     r1   CMIP6      Michel
# 3             CanESM5       r1i1p2f1  historical     r1   CMIP6      Michel
# 4             CanESM5       r1i1p2f1  historical     r1   CMIP6      Michel
# ...               ...            ...         ...    ...     ...         ...
# 3472866    NorESM2-MM       r1i1p1f1      ssp370     r1   CMIP6   Dominique
# 3472867    NorESM2-MM       r1i1p1f1      ssp370     r1   CMIP6   Dominique
# 3472868    NorESM2-MM       r1i1p1f1      ssp370     r1   CMIP6   Dominique
# 3472869    NorESM2-MM       r1i1p1f1      ssp370     r1   CMIP6   Dominique
# 3472870    NorESM2-MM       r1i1p1f1      ssp370     r1   CMIP6   Dominique
#
#              statut source activity  \
# 0        disponible  CRCM5    MRCC5
# 1        disponible  CRCM5    MRCC5
# 2        disponible  CRCM5    MRCC5
# 3        disponible  CRCM5    MRCC5
# 4        disponible  CRCM5    MRCC5
# ...             ...    ...      ...
# 3472866  disponible  CRCM5    MRCC5
# 3472867  disponible  CRCM5    MRCC5
# 3472868  disponible  CRCM5    MRCC5
# 3472869  disponible  CRCM5    MRCC5
# 3472870  disponible  CRCM5    MRCC5
#
#                                                         id
# 0        CMIP6_MRCC5_CanESM5_r1i1p2f1_OURANOS_CRCM5_his...
# 1        CMIP6_MRCC5_CanESM5_r1i1p2f1_OURANOS_CRCM5_his...
# 2        CMIP6_MRCC5_CanESM5_r1i1p2f1_OURANOS_CRCM5_his...
# 3        CMIP6_MRCC5_CanESM5_r1i1p2f1_OURANOS_CRCM5_his...
# 4        CMIP6_MRCC5_CanESM5_r1i1p2f1_OURANOS_CRCM5_his...
# ...                                                    ...
# 3472866  CMIP6_MRCC5_NorESM2-MM_r1i1p1f1_OURANOS_CRCM5_...
# 3472867  CMIP6_MRCC5_NorESM2-MM_r1i1p1f1_OURANOS_CRCM5_...
# 3472868  CMIP6_MRCC5_NorESM2-MM_r1i1p1f1_OURANOS_CRCM5_...
# 3472869  CMIP6_MRCC5_NorESM2-MM_r1i1p1f1_OURANOS_CRCM5_...
# 3472870  CMIP6_MRCC5_NorESM2-MM_r1i1p1f1_OURANOS_CRCM5_...
#
# [3472871 rows x 24 columns]

# %%
# Out:
# True

# %%
import xarray as xr

file = "/exec/braun/data/obsflow/extracted/GovCan_CanHomT-daily_CAN_station-tas_D_extracted.zarr"
ds_stat = xr.open_dataset(file, engine='zarr')
display(ds_stat)

file = "/exec/braun/data/obsflow/extracted/GovCan_CaSR_NAM_reconstruction_D_extracted.zarr"
ds_grd = xr.open_dataset(file, engine='zarr')
display(ds_grd)
# Out:
# <xarray.Dataset> Size: 35MB
# Dimensions:       (station: 110, time: 26298)
# Coordinates:
#     beginyear     (station) datetime64[ns] 880B ...
#     elevation     (station) int64 880B ...
#     endyear       (station) datetime64[ns] 880B ...
#     lat           (station) float64 880B ...
#     lon           (station) float64 880B ...
#     prov          (station) <U4 2kB ...
#   * station       (station) object 880B '6101335' '7010565' ... '7117823'
#     station_name  (station) <U30 13kB ...
#   * time          (time) datetime64[ns] 210kB 1950-01-01 ... 2021-12-31
#     timezone      (station) <U19 8kB ...
# Data variables:
#     tas           (station, time) float32 12MB ...
#     tasmax        (station, time) float32 12MB ...
#     tasmin        (station, time) float32 12MB ...
# Attributes: (12/36)
#     Conventions:             CF-1.9
#     cat:_data_format_:       zarr
#     cat:date_end:            2024-12-31 23:00:00
#     cat:date_start:          1949-01-01 00:00:00
#     cat:domain:              Quebec
#     cat:frequency:           day
#     ...                      ...
#     realm:                   atmos
#     source:                  CanHomT-daily
#     summary:                 Canada’s Fourth Generation of Homogenized Surfac...
#     title:                   CanHomT-Daily
#     type:                    station-obs
#     version:                 v4
# <xarray.Dataset> Size: 8GB
# Dimensions:       (time: 16071, rlat: 189, rlon: 162)
# Coordinates:
#     lat           (rlat, rlon) float32 122kB ...
#     lon           (rlat, rlon) float32 122kB ...
#   * rlat          (rlat) float32 756B -11.52 -11.43 -11.34 ... 5.22 5.31 5.4
#   * rlon          (rlon) float32 648B 6.633 6.723 6.813 ... 20.94 21.03 21.12
#     rotated_pole  |S1 1B ...
#   * time          (time) datetime64[ns] 129kB 1980-01-01 ... 2023-12-31
# Data variables:
#     pr            (time, rlat, rlon) float32 2GB ...
#     tas           (time, rlat, rlon) float32 2GB ...
#     tasmax        (time, rlat, rlon) float32 2GB ...
#     tasmin        (time, rlat, rlon) float32 2GB ...
# Attributes: (12/37)
#     Conventions:             CF-1.8
#     Remarks:                 Original variable names are following the conven...
#     cat:_data_format_:       zarr
#     cat:date_end:            2023-12-31 23:00:00
#     cat:date_start:          1980-01-01 00:00:00
#     cat:domain:              Quebec
#     ...                      ...
#     table_date:              2025-02-13
#     table_id:                eccc
#     terms_of_use:            Canadian Surface Reanalysis data users should ac...
#     title:                   Canadian Surface Reanalysis (CaSR) / Réanalyse ...
#     type:                    reconstruction
#     version:                 v3.1

# %%
rechunk = {key:30 for key in ds_grd.sizes}
rechunk
# Out:
# {'time': 30, 'rlat': 30, 'rlon': 30}
