# %%
import xscen as xs
import xarray as xr
from xscen.config import CONFIG

# Load configuration
xs.load_config(
    "../paths_obs.yml", "../config_obs.yml", verbose=(__name__ == "__main__"), reset=True
)

# %%
pcat = xs.ProjectCatalog(CONFIG["paths"]["project_catalog"])
df = pcat.df

# %%
list(df.columns)
# Out:
# ['id',
#  'type',
#  'processing_level',
#  'bias_adjust_institution',
#  'bias_adjust_project',
#  'mip_era',
#  'activity',
#  'driving_model',
#  'driving_member',
#  'institution',
#  'source',
#  'experiment',
#  'member',
#  'xrfreq',
#  'frequency',
#  'variable',
#  'domain',
#  'date_start',
#  'date_end',
#  'version',
#  'format',
#  'path',
#  'performance_base']

# %%
df_trimmed = df[['id','type','processing_level','institution','source','variable','xrfreq','frequency','date_start','date_end']]

# %%
list(df_trimmed['processing_level'].unique())
# Out:
# ['extracted',
#  'indicators',
#  'climatology',
#  'performance',
#  'regional_mean',
#  'coherence']

# %% [markdown]
# ## Extracted

# %%
extracted = df_trimmed[df_trimmed['processing_level']=='extracted']
extracted
# Out:
#                                    id            type processing_level  \
# 0  ECMWF_ERA5-Land_NAM_reconstruction  reconstruction        extracted
# 1      GovCan_RDRS_NAM_reconstruction  reconstruction        extracted
# 2      GovCan_CaSR_NAM_reconstruction  reconstruction        extracted
# 3   USask_EMDNA_OI_NAM_reconstruction  reconstruction        extracted
# 4   PCIC_PCICBlend_CAN_reconstruction  reconstruction        extracted
# 5        GovCan_AHCCD_CAN_station-tas     station-tas        extracted
# 6         GovCan_AHCCD_CAN_station-pr      station-pr        extracted
#
#   institution     source                   variable xrfreq frequency  \
# 0       ECMWF  ERA5-Land  (pr, tasmax, tasmin, tas)      D       day
# 1      GovCan  CaSR v2.1  (pr, tasmax, tasmin, tas)      D       day
# 2      GovCan  CaSR v3.1  (pr, tasmax, tasmin, tas)      D       day
# 3       USask      EMDNA  (pr, tasmax, tasmin, tas)      D       day
# 4        PCIC  PCICBlend  (pr, tasmax, tasmin, tas)      D       day
# 5      GovCan      AHCCD      (tasmax, tasmin, tas)      D       day
# 6      GovCan      AHCCD                      (pr,)      D       day
#
#   date_start   date_end
# 0 1980-01-01 2025-05-31
# 1 1980-01-01 2018-12-31
# 2 1980-01-01 2023-12-31
# 3 1980-01-01 2018-12-31
# 4 1980-01-01 2012-12-31
# 5 1980-01-01 2023-12-31
# 6 1980-01-01 2017-12-31

# %% [markdown]
# ## Indicators

# %%
indicators = df_trimmed[df_trimmed['processing_level']=='indicators']
indicators
# Out:
#                                     id            type processing_level  \
# 7   ECMWF_ERA5-Land_NAM_reconstruction  reconstruction       indicators
# 8   ECMWF_ERA5-Land_NAM_reconstruction  reconstruction       indicators
# 9   ECMWF_ERA5-Land_NAM_reconstruction  reconstruction       indicators
# 10  ECMWF_ERA5-Land_NAM_reconstruction  reconstruction       indicators
# 11  ECMWF_ERA5-Land_NAM_reconstruction  reconstruction       indicators
# 12  ECMWF_ERA5-Land_NAM_reconstruction  reconstruction       indicators
# 13  ECMWF_ERA5-Land_NAM_reconstruction  reconstruction       indicators
# 14  ECMWF_ERA5-Land_NAM_reconstruction  reconstruction       indicators
# 15         GovCan_AHCCD_CAN_station-pr      station-pr       indicators
# 16         GovCan_AHCCD_CAN_station-pr      station-pr       indicators
# 17        GovCan_AHCCD_CAN_station-tas     station-tas       indicators
# 18        GovCan_AHCCD_CAN_station-tas     station-tas       indicators
# 19        GovCan_AHCCD_CAN_station-tas     station-tas       indicators
# 20        GovCan_AHCCD_CAN_station-tas     station-tas       indicators
# 21        GovCan_AHCCD_CAN_station-tas     station-tas       indicators
# 22        GovCan_AHCCD_CAN_station-tas     station-tas       indicators
# 23      GovCan_CaSR_NAM_reconstruction  reconstruction       indicators
# 24      GovCan_CaSR_NAM_reconstruction  reconstruction       indicators
# 25      GovCan_CaSR_NAM_reconstruction  reconstruction       indicators
# 26      GovCan_CaSR_NAM_reconstruction  reconstruction       indicators
# 27      GovCan_CaSR_NAM_reconstruction  reconstruction       indicators
# 28      GovCan_CaSR_NAM_reconstruction  reconstruction       indicators
# 29      GovCan_CaSR_NAM_reconstruction  reconstruction       indicators
# 30      GovCan_CaSR_NAM_reconstruction  reconstruction       indicators
# 31      GovCan_RDRS_NAM_reconstruction  reconstruction       indicators
# 32      GovCan_RDRS_NAM_reconstruction  reconstruction       indicators
# 33      GovCan_RDRS_NAM_reconstruction  reconstruction       indicators
# 34      GovCan_RDRS_NAM_reconstruction  reconstruction       indicators
# 35      GovCan_RDRS_NAM_reconstruction  reconstruction       indicators
# 36      GovCan_RDRS_NAM_reconstruction  reconstruction       indicators
# 37      GovCan_RDRS_NAM_reconstruction  reconstruction       indicators
# 38      GovCan_RDRS_NAM_reconstruction  reconstruction       indicators
# 39   PCIC_PCICBlend_CAN_reconstruction  reconstruction       indicators
# 40   PCIC_PCICBlend_CAN_reconstruction  reconstruction       indicators
# 41   PCIC_PCICBlend_CAN_reconstruction  reconstruction       indicators
# 42   PCIC_PCICBlend_CAN_reconstruction  reconstruction       indicators
# 43   PCIC_PCICBlend_CAN_reconstruction  reconstruction       indicators
# 44   PCIC_PCICBlend_CAN_reconstruction  reconstruction       indicators
# 45   PCIC_PCICBlend_CAN_reconstruction  reconstruction       indicators
# 46   PCIC_PCICBlend_CAN_reconstruction  reconstruction       indicators
# 47   USask_EMDNA_OI_NAM_reconstruction  reconstruction       indicators
# 48   USask_EMDNA_OI_NAM_reconstruction  reconstruction       indicators
# 49   USask_EMDNA_OI_NAM_reconstruction  reconstruction       indicators
# 50   USask_EMDNA_OI_NAM_reconstruction  reconstruction       indicators
# 51   USask_EMDNA_OI_NAM_reconstruction  reconstruction       indicators
# 52   USask_EMDNA_OI_NAM_reconstruction  reconstruction       indicators
# 53   USask_EMDNA_OI_NAM_reconstruction  reconstruction       indicators
# 54   USask_EMDNA_OI_NAM_reconstruction  reconstruction       indicators
#
#    institution     source             variable  xrfreq frequency date_start  \
# 7        ECMWF  ERA5-Land    (tn_mean_annual,)  YS-JAN        yr 1980-01-01
# 8        ECMWF  ERA5-Land  (tn_mean_seasonal,)  QS-DEC       qtr 1980-03-01
# 9        ECMWF  ERA5-Land    (pr_mean_annual,)  YS-JAN        yr 1980-01-01
# 10       ECMWF  ERA5-Land  (pr_mean_seasonal,)  QS-DEC       qtr 1980-03-01
# 11       ECMWF  ERA5-Land    (tg_mean_annual,)  YS-JAN        yr 1980-01-01
# 12       ECMWF  ERA5-Land  (tg_mean_seasonal,)  QS-DEC       qtr 1980-03-01
# 13       ECMWF  ERA5-Land    (tx_mean_annual,)  YS-JAN        yr 1980-01-01
# 14       ECMWF  ERA5-Land  (tx_mean_seasonal,)  QS-DEC       qtr 1980-03-01
# 15      GovCan      AHCCD    (pr_mean_annual,)  YS-JAN        yr 1980-01-01
# 16      GovCan      AHCCD  (pr_mean_seasonal,)  QS-DEC       qtr 1980-03-01
# 17      GovCan      AHCCD    (tn_mean_annual,)  YS-JAN        yr 1980-01-01
# 18      GovCan      AHCCD  (tn_mean_seasonal,)  QS-DEC       qtr 1980-03-01
# 19      GovCan      AHCCD    (tg_mean_annual,)  YS-JAN        yr 1980-01-01
# 20      GovCan      AHCCD  (tg_mean_seasonal,)  QS-DEC       qtr 1980-03-01
# 21      GovCan      AHCCD    (tx_mean_annual,)  YS-JAN        yr 1980-01-01
# 22      GovCan      AHCCD  (tx_mean_seasonal,)  QS-DEC       qtr 1980-03-01
# 23      GovCan  CaSR v3.1    (tn_mean_annual,)  YS-JAN        yr 1980-01-01
# 24      GovCan  CaSR v3.1  (tn_mean_seasonal,)  QS-DEC       qtr 1980-03-01
# 25      GovCan  CaSR v3.1    (pr_mean_annual,)  YS-JAN        yr 1980-01-01
# 26      GovCan  CaSR v3.1  (pr_mean_seasonal,)  QS-DEC       qtr 1980-03-01
# 27      GovCan  CaSR v3.1    (tg_mean_annual,)  YS-JAN        yr 1980-01-01
# 28      GovCan  CaSR v3.1  (tg_mean_seasonal,)  QS-DEC       qtr 1980-03-01
# 29      GovCan  CaSR v3.1    (tx_mean_annual,)  YS-JAN        yr 1980-01-01
# 30      GovCan  CaSR v3.1  (tx_mean_seasonal,)  QS-DEC       qtr 1980-03-01
# 31      GovCan  CaSR v2.1    (tn_mean_annual,)  YS-JAN        yr 1980-01-01
# 32      GovCan  CaSR v2.1  (tn_mean_seasonal,)  QS-DEC       qtr 1980-03-01
# 33      GovCan  CaSR v2.1    (pr_mean_annual,)  YS-JAN        yr 1980-01-01
# 34      GovCan  CaSR v2.1  (pr_mean_seasonal,)  QS-DEC       qtr 1980-03-01
# 35      GovCan  CaSR v2.1    (tg_mean_annual,)  YS-JAN        yr 1980-01-01
# 36      GovCan  CaSR v2.1  (tg_mean_seasonal,)  QS-DEC       qtr 1980-03-01
# 37      GovCan  CaSR v2.1    (tx_mean_annual,)  YS-JAN        yr 1980-01-01
# 38      GovCan  CaSR v2.1  (tx_mean_seasonal,)  QS-DEC       qtr 1980-03-01
# 39        PCIC  PCICBlend    (tn_mean_annual,)  YS-JAN        yr 1980-01-01
# 40        PCIC  PCICBlend  (tn_mean_seasonal,)  QS-DEC       qtr 1980-03-01
# 41        PCIC  PCICBlend    (pr_mean_annual,)  YS-JAN        yr 1980-01-01
# 42        PCIC  PCICBlend  (pr_mean_seasonal,)  QS-DEC       qtr 1980-03-01
# 43        PCIC  PCICBlend    (tg_mean_annual,)  YS-JAN        yr 1980-01-01
# 44        PCIC  PCICBlend  (tg_mean_seasonal,)  QS-DEC       qtr 1980-03-01
# 45        PCIC  PCICBlend    (tx_mean_annual,)  YS-JAN        yr 1980-01-01
# 46        PCIC  PCICBlend  (tx_mean_seasonal,)  QS-DEC       qtr 1980-03-01
# 47       USask      EMDNA    (tn_mean_annual,)  YS-JAN        yr 1980-01-01
# 48       USask      EMDNA  (tn_mean_seasonal,)  QS-DEC       qtr 1980-03-01
# 49       USask      EMDNA    (pr_mean_annual,)  YS-JAN        yr 1980-01-01
# 50       USask      EMDNA  (pr_mean_seasonal,)  QS-DEC       qtr 1980-03-01
# 51       USask      EMDNA    (tg_mean_annual,)  YS-JAN        yr 1980-01-01
# 52       USask      EMDNA  (tg_mean_seasonal,)  QS-DEC       qtr 1980-03-01
# 53       USask      EMDNA    (tx_mean_annual,)  YS-JAN        yr 1980-01-01
# 54       USask      EMDNA  (tx_mean_seasonal,)  QS-DEC       qtr 1980-03-01
#
#      date_end
# 7  2025-01-01
# 8  2025-03-01
# 9  2025-01-01
# 10 2025-03-01
# 11 2025-01-01
# 12 2025-03-01
# 13 2025-01-01
# 14 2025-03-01
# 15 2017-01-01
# 16 2017-12-01
# 17 2023-01-01
# 18 2023-12-01
# 19 2023-01-01
# 20 2023-12-01
# 21 2023-01-01
# 22 2023-12-01
# 23 2023-01-01
# 24 2023-12-01
# 25 2023-01-01
# 26 2023-12-01
# 27 2023-01-01
# 28 2023-12-01
# 29 2023-01-01
# 30 2023-12-01
# 31 2018-01-01
# 32 2018-12-01
# 33 2018-01-01
# 34 2018-12-01
# 35 2018-01-01
# 36 2018-12-01
# 37 2018-01-01
# 38 2018-12-01
# 39 2012-01-01
# 40 2012-12-01
# 41 2012-01-01
# 42 2012-12-01
# 43 2012-01-01
# 44 2012-12-01
# 45 2012-01-01
# 46 2012-12-01
# 47 2018-01-01
# 48 2018-12-01
# 49 2018-01-01
# 50 2018-12-01
# 51 2018-01-01
# 52 2018-12-01
# 53 2018-01-01
# 54 2018-12-01

# %% [markdown]
# ## Climatology

# %%
climatology = df_trimmed[df_trimmed['processing_level']=='climatology']
climatology
# Out:
#                                      id            type processing_level  \
# 55   ECMWF_ERA5-Land_NAM_reconstruction  reconstruction      climatology
# 56   ECMWF_ERA5-Land_NAM_reconstruction  reconstruction      climatology
# 57   ECMWF_ERA5-Land_NAM_reconstruction  reconstruction      climatology
# 58   ECMWF_ERA5-Land_NAM_reconstruction  reconstruction      climatology
# 59   ECMWF_ERA5-Land_NAM_reconstruction  reconstruction      climatology
# ..                                  ...             ...              ...
# 122   USask_EMDNA_OI_NAM_reconstruction  reconstruction      climatology
# 123   USask_EMDNA_OI_NAM_reconstruction  reconstruction      climatology
# 124   USask_EMDNA_OI_NAM_reconstruction  reconstruction      climatology
# 125   USask_EMDNA_OI_NAM_reconstruction  reconstruction      climatology
# 126   USask_EMDNA_OI_NAM_reconstruction  reconstruction      climatology
#
#     institution     source                       variable  xrfreq frequency  \
# 55        ECMWF  ERA5-Land  (tn_mean_seasonal_clim_mean,)  QS-DEC       qtr
# 56        ECMWF  ERA5-Land  (pr_mean_seasonal_clim_mean,)  QS-DEC       qtr
# 57        ECMWF  ERA5-Land  (tg_mean_seasonal_clim_mean,)  QS-DEC       qtr
# 58        ECMWF  ERA5-Land  (tx_mean_seasonal_clim_mean,)  QS-DEC       qtr
# 59        ECMWF  ERA5-Land   (tg_mean_seasonal_clim_std,)  QS-DEC       qtr
# ..          ...        ...                            ...     ...       ...
# 122       USask      EMDNA    (pr_mean_annual_clim_mean,)  YS-JAN        yr
# 123       USask      EMDNA    (tg_mean_annual_clim_mean,)  YS-JAN        yr
# 124       USask      EMDNA    (tx_mean_annual_clim_mean,)  YS-JAN        yr
# 125       USask      EMDNA     (tg_mean_annual_clim_std,)  YS-JAN        yr
# 126       USask      EMDNA     (pr_mean_annual_clim_std,)  YS-JAN        yr
#
#     date_start   date_end
# 55  1980-03-01 2025-03-01
# 56  1980-03-01 2025-03-01
# 57  1980-03-01 2025-03-01
# 58  1980-03-01 2025-03-01
# 59  1980-03-01 2025-03-01
# ..         ...        ...
# 122 1980-01-01 2018-01-01
# 123 1980-01-01 2018-01-01
# 124 1980-01-01 2018-01-01
# 125 1980-01-01 2018-01-01
# 126 1980-01-01 2018-01-01
#
# [72 rows x 10 columns]

# %% [markdown]
# ## Performance

# %%
performance = df_trimmed[df_trimmed['processing_level']=='performance']
performance
# Out:
#                                      id            type processing_level  \
# 127   USask_EMDNA_OI_NAM_reconstruction  reconstruction      performance
# 128      GovCan_CaSR_NAM_reconstruction  reconstruction      performance
# 129   PCIC_PCICBlend_CAN_reconstruction  reconstruction      performance
# 130      GovCan_RDRS_NAM_reconstruction  reconstruction      performance
# 131  ECMWF_ERA5-Land_NAM_reconstruction  reconstruction      performance
# 132  ECMWF_ERA5-Land_NAM_reconstruction  reconstruction      performance
# 133      GovCan_CaSR_NAM_reconstruction  reconstruction      performance
# 134      GovCan_RDRS_NAM_reconstruction  reconstruction      performance
# 135   PCIC_PCICBlend_CAN_reconstruction  reconstruction      performance
# 136   USask_EMDNA_OI_NAM_reconstruction  reconstruction      performance
# 137   PCIC_PCICBlend_CAN_reconstruction  reconstruction      performance
# 138   USask_EMDNA_OI_NAM_reconstruction  reconstruction      performance
# 139      GovCan_RDRS_NAM_reconstruction  reconstruction      performance
# 140      GovCan_CaSR_NAM_reconstruction  reconstruction      performance
# 141  ECMWF_ERA5-Land_NAM_reconstruction  reconstruction      performance
# 142  ECMWF_ERA5-Land_NAM_reconstruction  reconstruction      performance
# 143   USask_EMDNA_OI_NAM_reconstruction  reconstruction      performance
# 144      GovCan_CaSR_NAM_reconstruction  reconstruction      performance
# 145   PCIC_PCICBlend_CAN_reconstruction  reconstruction      performance
# 146      GovCan_RDRS_NAM_reconstruction  reconstruction      performance
#
#     institution     source                  variable xrfreq frequency  \
# 127       USask      EMDNA    (tg_mean_annual_rmse,)     fx        yr
# 128      GovCan  CaSR v3.1    (tg_mean_annual_rmse,)     fx        yr
# 129        PCIC  PCICBlend    (tg_mean_annual_rmse,)     fx        yr
# 130      GovCan  CaSR v2.1    (tg_mean_annual_rmse,)     fx        yr
# 131       ECMWF  ERA5-Land    (tg_mean_annual_rmse,)     fx        yr
# 132       ECMWF  ERA5-Land  (tg_mean_seasonal_rmse,)     fx       qtr
# 133      GovCan  CaSR v3.1  (tg_mean_seasonal_rmse,)     fx       qtr
# 134      GovCan  CaSR v2.1  (tg_mean_seasonal_rmse,)     fx       qtr
# 135        PCIC  PCICBlend  (tg_mean_seasonal_rmse,)     fx       qtr
# 136       USask      EMDNA  (tg_mean_seasonal_rmse,)     fx       qtr
# 137        PCIC  PCICBlend    (pr_mean_annual_rmse,)     fx        yr
# 138       USask      EMDNA    (pr_mean_annual_rmse,)     fx        yr
# 139      GovCan  CaSR v2.1    (pr_mean_annual_rmse,)     fx        yr
# 140      GovCan  CaSR v3.1    (pr_mean_annual_rmse,)     fx        yr
# 141       ECMWF  ERA5-Land    (pr_mean_annual_rmse,)     fx        yr
# 142       ECMWF  ERA5-Land  (pr_mean_seasonal_rmse,)     fx       qtr
# 143       USask      EMDNA  (pr_mean_seasonal_rmse,)     fx       qtr
# 144      GovCan  CaSR v3.1  (pr_mean_seasonal_rmse,)     fx       qtr
# 145        PCIC  PCICBlend  (pr_mean_seasonal_rmse,)     fx       qtr
# 146      GovCan  CaSR v2.1  (pr_mean_seasonal_rmse,)     fx       qtr
#
#     date_start   date_end
# 127 1980-01-01 2018-01-01
# 128 1980-01-01 2023-01-01
# 129 1980-01-01 2012-01-01
# 130 1980-01-01 2018-01-01
# 131 1980-01-01 2025-01-01
# 132 1980-03-01 2025-03-01
# 133 1980-03-01 2023-12-01
# 134 1980-03-01 2018-12-01
# 135 1980-03-01 2012-12-01
# 136 1980-03-01 2018-12-01
# 137 1980-01-01 2012-01-01
# 138 1980-01-01 2018-01-01
# 139 1980-01-01 2018-01-01
# 140 1980-01-01 2023-01-01
# 141 1980-01-01 2025-01-01
# 142 1980-03-01 2025-03-01
# 143 1980-03-01 2018-12-01
# 144 1980-03-01 2023-12-01
# 145 1980-03-01 2012-12-01
# 146 1980-03-01 2018-12-01

# %% [markdown]
# ## Regional mean

# %%
regional_mean = df_trimmed[df_trimmed['processing_level']=='regional_mean']
regional_mean
# Out:
#            id            type processing_level institution    source  \
# 147  multiple  reconstruction    regional_mean       ECMWF  multiple
# 148  multiple  reconstruction    regional_mean        PCIC  multiple
# 149  multiple  reconstruction    regional_mean        PCIC  multiple
# 150  multiple  reconstruction    regional_mean        PCIC  multiple
#
#                      variable xrfreq frequency date_start   date_end
# 147    (tg_mean_annual_rmse,)     fx        yr 1980-01-01 2025-01-01
# 148  (tg_mean_seasonal_rmse,)     fx       qtr 1980-03-01 2012-12-01
# 149    (pr_mean_annual_rmse,)     fx        yr 1980-01-01 2012-01-01
# 150  (pr_mean_seasonal_rmse,)     fx       qtr 1980-03-01 2012-12-01

# %% [markdown]
# ## Coherence

# %%
coherence = df_trimmed[df_trimmed['processing_level']=='coherence']
coherence
# Out:
#            id            type processing_level institution    source  \
# 151  multiple  reconstruction        coherence        PCIC  multiple
# 152  multiple  reconstruction        coherence        PCIC  multiple
# 153  multiple  reconstruction        coherence        PCIC  multiple
# 154  multiple  reconstruction        coherence       ECMWF  multiple
#
#                           variable xrfreq frequency date_start   date_end
# 151    (tg_mean_annual_clim_mean,)     fx        yr 1980-01-01 2012-01-01
# 152    (pr_mean_annual_clim_mean,)     fx        yr 1980-01-01 2012-01-01
# 153  (tg_mean_seasonal_clim_mean,)     fx       qtr 1980-03-01 2012-12-01
# 154  (pr_mean_seasonal_clim_mean,)     fx       qtr 1980-03-01 2025-03-01
