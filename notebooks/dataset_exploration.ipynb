# %%
import xscen as xs
import xarray as xr
from xscen.config import CONFIG

# Load configuration
xs.load_config(
    "../paths_obs.yml", "../config_obs.yml", verbose=(__name__ == "__main__"), reset=True
)
# Out:
# 2025-07-16 11:02:53 INFO     xscen.config    Updated the config with ../paths_obs.yml.
# 2025-07-16 11:02:53 INFO     xscen.config    Updated the config with ../config_obs.yml.

# %%
pcat = xs.ProjectCatalog(CONFIG["paths"]["project_catalog"])
df = pcat.df

# %%
list(df.columns)
# Out:
# ['id',
#  'type',
#  'processing_level',
#  'bias_adjust_institution',
#  'bias_adjust_project',
#  'mip_era',
#  'activity',
#  'driving_model',
#  'institution',
#  'source',
#  'experiment',
#  'member',
#  'xrfreq',
#  'frequency',
#  'variable',
#  'domain',
#  'date_start',
#  'date_end',
#  'version',
#  'format',
#  'path',
#  'performance_base']

# %%
df_trimmed = df[['id','type','processing_level','institution','source','variable','xrfreq','frequency','date_start','date_end']]

# %%
list(df_trimmed['processing_level'].unique())
# Out:
# ['extracted', 'indicators', 'climatology', 'performance', 'spatial_mean']

# %% [markdown]
# ## Extracted

# %%
extracted = df_trimmed[df_trimmed['processing_level']=='extracted']
extracted
# Out:
#                                    id            type processing_level  \
# 0  ECMWF_ERA5-Land_NAM_reconstruction  reconstruction        extracted
# 1      GovCan_RDRS_NAM_reconstruction  reconstruction        extracted
# 2      GovCan_CaSR_NAM_reconstruction  reconstruction        extracted
# 3   USask_EMDNA_OI_NAM_reconstruction  reconstruction        extracted
# 4   PCIC_PCICBlend_CAN_reconstruction  reconstruction        extracted
# 5        GovCan_AHCCD_CAN_station-tas     station-tas        extracted
# 6         GovCan_AHCCD_CAN_station-pr      station-pr        extracted
#
#   institution     source                   variable xrfreq frequency  \
# 0       ECMWF  ERA5-Land  (tas, pr, tasmin, tasmax)      D       day
# 1      GovCan       RDRS  (tas, pr, tasmin, tasmax)      D       day
# 2      GovCan       CaSR  (tas, pr, tasmin, tasmax)      D       day
# 3       USask      EMDNA  (tas, tasmax, tasmin, pr)      D       day
# 4        PCIC  PCICBlend  (tas, tasmax, tasmin, pr)      D       day
# 5      GovCan      AHCCD      (tas, tasmin, tasmax)      D       day
# 6      GovCan      AHCCD                      (pr,)      D       day
#
#   date_start   date_end
# 0 1980-01-01 2025-05-31
# 1 1980-01-01 2018-12-31
# 2 1980-01-01 2023-12-31
# 3 1980-01-01 2018-12-31
# 4 1980-01-01 2012-12-31
# 5 1980-01-01 2023-12-31
# 6 1980-01-01 2017-12-31

# %% [markdown]
# ## Indicators

# %%
indicators = df_trimmed[df_trimmed['processing_level']=='indicators']
indicators
# Out:
#                                     id            type processing_level  \
# 7   ECMWF_ERA5-Land_NAM_reconstruction  reconstruction       indicators
# 8   ECMWF_ERA5-Land_NAM_reconstruction  reconstruction       indicators
# 9   ECMWF_ERA5-Land_NAM_reconstruction  reconstruction       indicators
# 10  ECMWF_ERA5-Land_NAM_reconstruction  reconstruction       indicators
# 11  ECMWF_ERA5-Land_NAM_reconstruction  reconstruction       indicators
# 12  ECMWF_ERA5-Land_NAM_reconstruction  reconstruction       indicators
# 13  ECMWF_ERA5-Land_NAM_reconstruction  reconstruction       indicators
# 14  ECMWF_ERA5-Land_NAM_reconstruction  reconstruction       indicators
# 15         GovCan_AHCCD_CAN_station-pr      station-pr       indicators
# 16         GovCan_AHCCD_CAN_station-pr      station-pr       indicators
# 17        GovCan_AHCCD_CAN_station-tas     station-tas       indicators
# 18        GovCan_AHCCD_CAN_station-tas     station-tas       indicators
# 19        GovCan_AHCCD_CAN_station-tas     station-tas       indicators
# 20        GovCan_AHCCD_CAN_station-tas     station-tas       indicators
# 21        GovCan_AHCCD_CAN_station-tas     station-tas       indicators
# 22        GovCan_AHCCD_CAN_station-tas     station-tas       indicators
# 23      GovCan_CaSR_NAM_reconstruction  reconstruction       indicators
# 24      GovCan_CaSR_NAM_reconstruction  reconstruction       indicators
# 25      GovCan_CaSR_NAM_reconstruction  reconstruction       indicators
# 26      GovCan_CaSR_NAM_reconstruction  reconstruction       indicators
# 27      GovCan_CaSR_NAM_reconstruction  reconstruction       indicators
# 28      GovCan_CaSR_NAM_reconstruction  reconstruction       indicators
# 29      GovCan_CaSR_NAM_reconstruction  reconstruction       indicators
# 30      GovCan_CaSR_NAM_reconstruction  reconstruction       indicators
# 31      GovCan_RDRS_NAM_reconstruction  reconstruction       indicators
# 32      GovCan_RDRS_NAM_reconstruction  reconstruction       indicators
# 33      GovCan_RDRS_NAM_reconstruction  reconstruction       indicators
# 34      GovCan_RDRS_NAM_reconstruction  reconstruction       indicators
# 35      GovCan_RDRS_NAM_reconstruction  reconstruction       indicators
# 36      GovCan_RDRS_NAM_reconstruction  reconstruction       indicators
# 37      GovCan_RDRS_NAM_reconstruction  reconstruction       indicators
# 38      GovCan_RDRS_NAM_reconstruction  reconstruction       indicators
# 39   PCIC_PCICBlend_CAN_reconstruction  reconstruction       indicators
# 40   PCIC_PCICBlend_CAN_reconstruction  reconstruction       indicators
# 41   PCIC_PCICBlend_CAN_reconstruction  reconstruction       indicators
# 42   PCIC_PCICBlend_CAN_reconstruction  reconstruction       indicators
# 43   PCIC_PCICBlend_CAN_reconstruction  reconstruction       indicators
# 44   PCIC_PCICBlend_CAN_reconstruction  reconstruction       indicators
# 45   PCIC_PCICBlend_CAN_reconstruction  reconstruction       indicators
# 46   PCIC_PCICBlend_CAN_reconstruction  reconstruction       indicators
# 47   USask_EMDNA_OI_NAM_reconstruction  reconstruction       indicators
# 48   USask_EMDNA_OI_NAM_reconstruction  reconstruction       indicators
# 49   USask_EMDNA_OI_NAM_reconstruction  reconstruction       indicators
# 50   USask_EMDNA_OI_NAM_reconstruction  reconstruction       indicators
# 51   USask_EMDNA_OI_NAM_reconstruction  reconstruction       indicators
# 52   USask_EMDNA_OI_NAM_reconstruction  reconstruction       indicators
# 53   USask_EMDNA_OI_NAM_reconstruction  reconstruction       indicators
# 54   USask_EMDNA_OI_NAM_reconstruction  reconstruction       indicators
#
#    institution     source             variable  xrfreq frequency date_start  \
# 7        ECMWF  ERA5-Land    (tn_mean_annual,)  YS-JAN        yr 1980-01-01
# 8        ECMWF  ERA5-Land  (tn_mean_seasonal,)  QS-DEC       qtr 1980-03-01
# 9        ECMWF  ERA5-Land    (pr_mean_annual,)  YS-JAN        yr 1980-01-01
# 10       ECMWF  ERA5-Land  (pr_mean_seasonal,)  QS-DEC       qtr 1980-03-01
# 11       ECMWF  ERA5-Land    (tx_mean_annual,)  YS-JAN        yr 1980-01-01
# 12       ECMWF  ERA5-Land  (tx_mean_seasonal,)  QS-DEC       qtr 1980-03-01
# 13       ECMWF  ERA5-Land    (tg_mean_annual,)  YS-JAN        yr 1980-01-01
# 14       ECMWF  ERA5-Land  (tg_mean_seasonal,)  QS-DEC       qtr 1980-03-01
# 15      GovCan      AHCCD    (pr_mean_annual,)  YS-JAN        yr 1980-01-01
# 16      GovCan      AHCCD  (pr_mean_seasonal,)  QS-DEC       qtr 1980-03-01
# 17      GovCan      AHCCD    (tn_mean_annual,)  YS-JAN        yr 1980-01-01
# 18      GovCan      AHCCD  (tn_mean_seasonal,)  QS-DEC       qtr 1980-03-01
# 19      GovCan      AHCCD    (tx_mean_annual,)  YS-JAN        yr 1980-01-01
# 20      GovCan      AHCCD  (tx_mean_seasonal,)  QS-DEC       qtr 1980-03-01
# 21      GovCan      AHCCD    (tg_mean_annual,)  YS-JAN        yr 1980-01-01
# 22      GovCan      AHCCD  (tg_mean_seasonal,)  QS-DEC       qtr 1980-03-01
# 23      GovCan       CaSR    (tn_mean_annual,)  YS-JAN        yr 1980-01-01
# 24      GovCan       CaSR  (tn_mean_seasonal,)  QS-DEC       qtr 1980-03-01
# 25      GovCan       CaSR    (pr_mean_annual,)  YS-JAN        yr 1980-01-01
# 26      GovCan       CaSR  (pr_mean_seasonal,)  QS-DEC       qtr 1980-03-01
# 27      GovCan       CaSR    (tx_mean_annual,)  YS-JAN        yr 1980-01-01
# 28      GovCan       CaSR  (tx_mean_seasonal,)  QS-DEC       qtr 1980-03-01
# 29      GovCan       CaSR    (tg_mean_annual,)  YS-JAN        yr 1980-01-01
# 30      GovCan       CaSR  (tg_mean_seasonal,)  QS-DEC       qtr 1980-03-01
# 31      GovCan       RDRS    (tn_mean_annual,)  YS-JAN        yr 1980-01-01
# 32      GovCan       RDRS  (tn_mean_seasonal,)  QS-DEC       qtr 1980-03-01
# 33      GovCan       RDRS    (pr_mean_annual,)  YS-JAN        yr 1980-01-01
# 34      GovCan       RDRS  (pr_mean_seasonal,)  QS-DEC       qtr 1980-03-01
# 35      GovCan       RDRS    (tx_mean_annual,)  YS-JAN        yr 1980-01-01
# 36      GovCan       RDRS  (tx_mean_seasonal,)  QS-DEC       qtr 1980-03-01
# 37      GovCan       RDRS    (tg_mean_annual,)  YS-JAN        yr 1980-01-01
# 38      GovCan       RDRS  (tg_mean_seasonal,)  QS-DEC       qtr 1980-03-01
# 39        PCIC  PCICBlend    (tn_mean_annual,)  YS-JAN        yr 1980-01-01
# 40        PCIC  PCICBlend  (tn_mean_seasonal,)  QS-DEC       qtr 1980-03-01
# 41        PCIC  PCICBlend    (pr_mean_annual,)  YS-JAN        yr 1980-01-01
# 42        PCIC  PCICBlend  (pr_mean_seasonal,)  QS-DEC       qtr 1980-03-01
# 43        PCIC  PCICBlend    (tx_mean_annual,)  YS-JAN        yr 1980-01-01
# 44        PCIC  PCICBlend  (tx_mean_seasonal,)  QS-DEC       qtr 1980-03-01
# 45        PCIC  PCICBlend    (tg_mean_annual,)  YS-JAN        yr 1980-01-01
# 46        PCIC  PCICBlend  (tg_mean_seasonal,)  QS-DEC       qtr 1980-03-01
# 47       USask      EMDNA    (tn_mean_annual,)  YS-JAN        yr 1980-01-01
# 48       USask      EMDNA  (tn_mean_seasonal,)  QS-DEC       qtr 1980-03-01
# 49       USask      EMDNA    (pr_mean_annual,)  YS-JAN        yr 1980-01-01
# 50       USask      EMDNA  (pr_mean_seasonal,)  QS-DEC       qtr 1980-03-01
# 51       USask      EMDNA    (tx_mean_annual,)  YS-JAN        yr 1980-01-01
# 52       USask      EMDNA  (tx_mean_seasonal,)  QS-DEC       qtr 1980-03-01
# 53       USask      EMDNA    (tg_mean_annual,)  YS-JAN        yr 1980-01-01
# 54       USask      EMDNA  (tg_mean_seasonal,)  QS-DEC       qtr 1980-03-01
#
#      date_end
# 7  2025-01-01
# 8  2025-03-01
# 9  2025-01-01
# 10 2025-03-01
# 11 2025-01-01
# 12 2025-03-01
# 13 2025-01-01
# 14 2025-03-01
# 15 2017-01-01
# 16 2017-12-01
# 17 2023-01-01
# 18 2023-12-01
# 19 2023-01-01
# 20 2023-12-01
# 21 2023-01-01
# 22 2023-12-01
# 23 2023-01-01
# 24 2023-12-01
# 25 2023-01-01
# 26 2023-12-01
# 27 2023-01-01
# 28 2023-12-01
# 29 2023-01-01
# 30 2023-12-01
# 31 2018-01-01
# 32 2018-12-01
# 33 2018-01-01
# 34 2018-12-01
# 35 2018-01-01
# 36 2018-12-01
# 37 2018-01-01
# 38 2018-12-01
# 39 2012-01-01
# 40 2012-12-01
# 41 2012-01-01
# 42 2012-12-01
# 43 2012-01-01
# 44 2012-12-01
# 45 2012-01-01
# 46 2012-12-01
# 47 2018-01-01
# 48 2018-12-01
# 49 2018-01-01
# 50 2018-12-01
# 51 2018-01-01
# 52 2018-12-01
# 53 2018-01-01
# 54 2018-12-01

# %% [markdown]
# ## Climatology

# %%
climatology = df_trimmed[df_trimmed['processing_level']=='climatology']
climatology
# Out:
#                                      id            type processing_level  \
# 55   ECMWF_ERA5-Land_NAM_reconstruction  reconstruction      climatology
# 56   ECMWF_ERA5-Land_NAM_reconstruction  reconstruction      climatology
# 57   ECMWF_ERA5-Land_NAM_reconstruction  reconstruction      climatology
# 58   ECMWF_ERA5-Land_NAM_reconstruction  reconstruction      climatology
# 59   ECMWF_ERA5-Land_NAM_reconstruction  reconstruction      climatology
# ..                                  ...             ...              ...
# 122   USask_EMDNA_OI_NAM_reconstruction  reconstruction      climatology
# 123   USask_EMDNA_OI_NAM_reconstruction  reconstruction      climatology
# 124   USask_EMDNA_OI_NAM_reconstruction  reconstruction      climatology
# 125   USask_EMDNA_OI_NAM_reconstruction  reconstruction      climatology
# 126   USask_EMDNA_OI_NAM_reconstruction  reconstruction      climatology
#
#     institution     source                       variable  xrfreq frequency  \
# 55        ECMWF  ERA5-Land  (tn_mean_seasonal_clim_mean,)  QS-DEC       qtr
# 56        ECMWF  ERA5-Land  (pr_mean_seasonal_clim_mean,)  QS-DEC       qtr
# 57        ECMWF  ERA5-Land  (tx_mean_seasonal_clim_mean,)  QS-DEC       qtr
# 58        ECMWF  ERA5-Land  (tg_mean_seasonal_clim_mean,)  QS-DEC       qtr
# 59        ECMWF  ERA5-Land   (tg_mean_seasonal_clim_std,)  QS-DEC       qtr
# ..          ...        ...                            ...     ...       ...
# 122       USask      EMDNA    (pr_mean_annual_clim_mean,)  YS-JAN        yr
# 123       USask      EMDNA    (tx_mean_annual_clim_mean,)  YS-JAN        yr
# 124       USask      EMDNA    (tg_mean_annual_clim_mean,)  YS-JAN        yr
# 125       USask      EMDNA     (tg_mean_annual_clim_std,)  YS-JAN        yr
# 126       USask      EMDNA     (pr_mean_annual_clim_std,)  YS-JAN        yr
#
#     date_start   date_end
# 55  1980-03-01 2025-03-01
# 56  1980-03-01 2025-03-01
# 57  1980-03-01 2025-03-01
# 58  1980-03-01 2025-03-01
# 59  1980-03-01 2025-03-01
# ..         ...        ...
# 122 1980-01-01 2018-01-01
# 123 1980-01-01 2018-01-01
# 124 1980-01-01 2018-01-01
# 125 1980-01-01 2018-01-01
# 126 1980-01-01 2018-01-01
#
# [72 rows x 10 columns]

# %% [markdown]
# ## Performance

# %%
performance = df_trimmed[df_trimmed['processing_level']=='performance']
performance
# Out:
#                                                 id   type processing_level  \
# 127       RDRS_Quebec_GovCan_AHCCD_CAN_station-tas  mixed      performance
# 128  ERA5-Land_Quebec_GovCan_AHCCD_CAN_station-tas  mixed      performance
# 129      EMDNA_Quebec_GovCan_AHCCD_CAN_station-tas  mixed      performance
# 130  PCICBlend_Quebec_GovCan_AHCCD_CAN_station-tas  mixed      performance
# 131       CaSR_Quebec_GovCan_AHCCD_CAN_station-tas  mixed      performance
# 132      EMDNA_Quebec_GovCan_AHCCD_CAN_station-tas  mixed      performance
# 133  ERA5-Land_Quebec_GovCan_AHCCD_CAN_station-tas  mixed      performance
# 134  PCICBlend_Quebec_GovCan_AHCCD_CAN_station-tas  mixed      performance
# 135       CaSR_Quebec_GovCan_AHCCD_CAN_station-tas  mixed      performance
# 136       RDRS_Quebec_GovCan_AHCCD_CAN_station-tas  mixed      performance
# 137        RDRS_Quebec_GovCan_AHCCD_CAN_station-pr  mixed      performance
# 138        CaSR_Quebec_GovCan_AHCCD_CAN_station-pr  mixed      performance
# 139   PCICBlend_Quebec_GovCan_AHCCD_CAN_station-pr  mixed      performance
# 140       EMDNA_Quebec_GovCan_AHCCD_CAN_station-pr  mixed      performance
# 141   ERA5-Land_Quebec_GovCan_AHCCD_CAN_station-pr  mixed      performance
# 142        RDRS_Quebec_GovCan_AHCCD_CAN_station-pr  mixed      performance
# 143        CaSR_Quebec_GovCan_AHCCD_CAN_station-pr  mixed      performance
# 144   ERA5-Land_Quebec_GovCan_AHCCD_CAN_station-pr  mixed      performance
# 145       EMDNA_Quebec_GovCan_AHCCD_CAN_station-pr  mixed      performance
# 146   PCICBlend_Quebec_GovCan_AHCCD_CAN_station-pr  mixed      performance
#
#     institution     source                  variable xrfreq frequency  \
# 127         NaN       RDRS    (tg_mean_annual_rmse,)     fx       NaN
# 128         NaN  ERA5-Land    (tg_mean_annual_rmse,)     fx       NaN
# 129         NaN      EMDNA    (tg_mean_annual_rmse,)     fx       NaN
# 130         NaN  PCICBlend    (tg_mean_annual_rmse,)     fx       NaN
# 131         NaN       CaSR    (tg_mean_annual_rmse,)     fx       NaN
# 132         NaN      EMDNA  (tg_mean_seasonal_rmse,)     fx       NaN
# 133         NaN  ERA5-Land  (tg_mean_seasonal_rmse,)     fx       NaN
# 134         NaN  PCICBlend  (tg_mean_seasonal_rmse,)     fx       NaN
# 135         NaN       CaSR  (tg_mean_seasonal_rmse,)     fx       NaN
# 136         NaN       RDRS  (tg_mean_seasonal_rmse,)     fx       NaN
# 137         NaN       RDRS    (pr_mean_annual_rmse,)     fx       NaN
# 138         NaN       CaSR    (pr_mean_annual_rmse,)     fx       NaN
# 139         NaN  PCICBlend    (pr_mean_annual_rmse,)     fx       NaN
# 140         NaN      EMDNA    (pr_mean_annual_rmse,)     fx       NaN
# 141         NaN  ERA5-Land    (pr_mean_annual_rmse,)     fx       NaN
# 142         NaN       RDRS  (pr_mean_seasonal_rmse,)     fx       NaN
# 143         NaN       CaSR  (pr_mean_seasonal_rmse,)     fx       NaN
# 144         NaN  ERA5-Land  (pr_mean_seasonal_rmse,)     fx       NaN
# 145         NaN      EMDNA  (pr_mean_seasonal_rmse,)     fx       NaN
# 146         NaN  PCICBlend  (pr_mean_seasonal_rmse,)     fx       NaN
#
#     date_start date_end
# 127        NaT      NaT
# 128        NaT      NaT
# 129        NaT      NaT
# 130        NaT      NaT
# 131        NaT      NaT
# 132        NaT      NaT
# 133        NaT      NaT
# 134        NaT      NaT
# 135        NaT      NaT
# 136        NaT      NaT
# 137        NaT      NaT
# 138        NaT      NaT
# 139        NaT      NaT
# 140        NaT      NaT
# 141        NaT      NaT
# 142        NaT      NaT
# 143        NaT      NaT
# 144        NaT      NaT
# 145        NaT      NaT
# 146        NaT      NaT

# %% [markdown]
# ## Spatial mean

# %%
spatial_mean = df_trimmed[df_trimmed['processing_level']=='spatial_mean']
spatial_mean
# Out:
#                  id   type processing_level institution    source  \
# 147  multiple_mixed  mixed     spatial_mean         NaN  multiple
# 148  multiple_mixed  mixed     spatial_mean         NaN  multiple
# 149  multiple_mixed  mixed     spatial_mean         NaN  multiple
# 150  multiple_mixed  mixed     spatial_mean         NaN  multiple
#
#                      variable xrfreq frequency date_start date_end
# 147    (tg_mean_annual_rmse,)     fx       NaN        NaT      NaT
# 148  (tg_mean_seasonal_rmse,)     fx       NaN        NaT      NaT
# 149    (pr_mean_annual_rmse,)     fx       NaN        NaT      NaT
# 150  (pr_mean_seasonal_rmse,)     fx       NaN        NaT      NaT

# %% [markdown]
# ## Checking periods

# %%
ds_dict = pcat.search(processing_level='indicators', frequency=['yr'],source='CaSR').to_dataset_dict()
ds_dict.keys()
# Out:
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'id.domain.processing_level.xrfreq'
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
# dict_keys(['GovCan_CaSR_NAM_reconstruction.Quebec.indicators.YS-JAN'])

# %%
ds = ds_dict['GovCan_CaSR_NAM_reconstruction.Quebec.indicators.YS-JAN']

# %%
ds.tg_mean_annual.attrs
# Out:
# {'cell_methods': 'time: mean (interval: 1 day) time: mean over days',
#  'description': 'Annual mean of daily mean temperature.',
#  'grid_mapping': 'rotated_pole',
#  'history': "[2025-07-14 17:08:30] tg_mean_annual: indicators_obs.TG_MEAN_ANNUAL(tas=tas) with options check_missing=wmo, missing_options={'nm': 11, 'nc': 5} - xclim version: 0.55.1",
#  'long_name': 'Mean daily mean temperature',
#  'original_variable': 'P_TT_1.5m',
#  'standard_name': 'air_temperature',
#  'units': '°C',
#  'units_metadata': 'temperature: unknown'}

# %%
ds_dict = pcat.search(processing_level='indicators', frequency=['yr']).to_dataset_dict()
for k in ds_dict.keys():
    print(k)
# Out:
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'id.domain.processing_level.xrfreq'
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='0' class='' max='7' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/7 00:00&lt;?]
#     </div>
# GovCan_CaSR_NAM_reconstruction.Quebec.indicators.YS-JAN
# ECMWF_ERA5-Land_NAM_reconstruction.Quebec.indicators.YS-JAN
# PCIC_PCICBlend_CAN_reconstruction.Quebec.indicators.YS-JAN
# USask_EMDNA_OI_NAM_reconstruction.Quebec.indicators.YS-JAN
# GovCan_AHCCD_CAN_station-pr.Quebec.indicators.YS-JAN
# GovCan_RDRS_NAM_reconstruction.Quebec.indicators.YS-JAN
# GovCan_AHCCD_CAN_station-tas.Quebec.indicators.YS-JAN
