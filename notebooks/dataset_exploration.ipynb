# %%
import xscen as xs
import xarray as xr
from xscen.config import CONFIG

# Load configuration
xs.load_config(
    "../paths_obs.yml", "../config_obs.yml", verbose=(__name__ == "__main__"), reset=True
)
# Out:
# 2025-07-04 13:12:28 INFO     xscen.config    Updated the config with ../paths_obs.yml.
# 2025-07-04 13:12:28 INFO     xscen.config    Updated the config with ../config_obs.yml.

# %%
pcat = xs.ProjectCatalog(CONFIG["paths"]["project_catalog"])
df = pcat.df

# %%
list(df.columns)
# Out:
# ['id',
#  'type',
#  'processing_level',
#  'bias_adjust_institution',
#  'bias_adjust_project',
#  'mip_era',
#  'activity',
#  'driving_model',
#  'institution',
#  'source',
#  'experiment',
#  'member',
#  'xrfreq',
#  'frequency',
#  'variable',
#  'domain',
#  'date_start',
#  'date_end',
#  'version',
#  'format',
#  'path',
#  'performance_base']

# %%
df_trimmed = df[['id','type','processing_level','institution','source','variable','frequency','date_start','date_end']]

# %%
list(df_trimmed['processing_level'].unique())
# Out:
# ['extracted', 'indicators', 'climatology', 'performance']

# %% [markdown]
# ## Extracted

# %%
extracted = df_trimmed[df_trimmed['processing_level']=='extracted']
extracted
# Out:
#                                    id            type processing_level  \
# 0  ECMWF_ERA5-Land_NAM_reconstruction  reconstruction        extracted
# 1      GovCan_RDRS_NAM_reconstruction  reconstruction        extracted
# 2      GovCan_CaSR_NAM_reconstruction  reconstruction        extracted
# 3   USask_EMDNA_OI_NAM_reconstruction  reconstruction        extracted
# 4   PCIC_PCICBlend_CAN_reconstruction  reconstruction        extracted
# 5        GovCan_AHCCD_CAN_station-tas     station-tas        extracted
# 6         GovCan_AHCCD_CAN_station-pr      station-pr        extracted
#
#   institution     source                   variable frequency date_start  \
# 0       ECMWF  ERA5-Land  (pr, tasmin, tasmax, tas)       day 1980-01-01
# 1      GovCan       RDRS  (pr, tasmin, tasmax, tas)       day 1980-01-01
# 2      GovCan       CaSR  (pr, tasmin, tasmax, tas)       day 1980-01-01
# 3       USask      EMDNA  (pr, tasmin, tasmax, tas)       day 1980-01-01
# 4        PCIC  PCICBlend  (pr, tasmin, tasmax, tas)       day 1980-01-01
# 5      GovCan      AHCCD      (tasmin, tasmax, tas)       day 1980-01-01
# 6      GovCan      AHCCD                      (pr,)       day 1980-01-01
#
#     date_end
# 0 2025-05-31
# 1 2018-12-31
# 2 2023-12-31
# 3 2018-12-31
# 4 2012-12-31
# 5 2023-12-31
# 6 2017-12-31

# %% [markdown]
# ## Indicators

# %%
indicators = df_trimmed[df_trimmed['processing_level']=='indicators']
indicators
# Out:
#                                     id            type processing_level  \
# 7   ECMWF_ERA5-Land_NAM_reconstruction  reconstruction       indicators
# 8   ECMWF_ERA5-Land_NAM_reconstruction  reconstruction       indicators
# 9          GovCan_AHCCD_CAN_station-pr      station-pr       indicators
# 10         GovCan_AHCCD_CAN_station-pr      station-pr       indicators
# 11        GovCan_AHCCD_CAN_station-tas     station-tas       indicators
# 12        GovCan_AHCCD_CAN_station-tas     station-tas       indicators
# 13      GovCan_CaSR_NAM_reconstruction  reconstruction       indicators
# 14      GovCan_CaSR_NAM_reconstruction  reconstruction       indicators
# 15      GovCan_RDRS_NAM_reconstruction  reconstruction       indicators
# 16      GovCan_RDRS_NAM_reconstruction  reconstruction       indicators
# 17   PCIC_PCICBlend_CAN_reconstruction  reconstruction       indicators
# 18   PCIC_PCICBlend_CAN_reconstruction  reconstruction       indicators
# 19   USask_EMDNA_OI_NAM_reconstruction  reconstruction       indicators
# 20   USask_EMDNA_OI_NAM_reconstruction  reconstruction       indicators
#
#    institution     source                              variable frequency  \
# 7        ECMWF  ERA5-Land      (tg_mean_annual, pr_mean_annual)        yr
# 8        ECMWF  ERA5-Land  (tg_mean_seasonal, pr_mean_seasonal)       qtr
# 9       GovCan      AHCCD                     (pr_mean_annual,)        yr
# 10      GovCan      AHCCD                   (pr_mean_seasonal,)       qtr
# 11      GovCan      AHCCD                     (tg_mean_annual,)        yr
# 12      GovCan      AHCCD                   (tg_mean_seasonal,)       qtr
# 13      GovCan       CaSR      (tg_mean_annual, pr_mean_annual)        yr
# 14      GovCan       CaSR  (tg_mean_seasonal, pr_mean_seasonal)       qtr
# 15      GovCan       RDRS      (tg_mean_annual, pr_mean_annual)        yr
# 16      GovCan       RDRS  (tg_mean_seasonal, pr_mean_seasonal)       qtr
# 17        PCIC  PCICBlend      (tg_mean_annual, pr_mean_annual)        yr
# 18        PCIC  PCICBlend  (tg_mean_seasonal, pr_mean_seasonal)       qtr
# 19       USask      EMDNA      (tg_mean_annual, pr_mean_annual)        yr
# 20       USask      EMDNA  (tg_mean_seasonal, pr_mean_seasonal)       qtr
#
#    date_start   date_end
# 7  1980-01-01 2025-01-01
# 8  1980-03-01 2025-03-01
# 9  1980-01-01 2017-01-01
# 10 1980-03-01 2017-12-01
# 11 1980-01-01 2023-01-01
# 12 1980-03-01 2023-12-01
# 13 1980-01-01 2023-01-01
# 14 1980-03-01 2023-12-01
# 15 1980-01-01 2018-01-01
# 16 1980-03-01 2018-12-01
# 17 1980-01-01 2012-01-01
# 18 1980-03-01 2012-12-01
# 19 1980-01-01 2018-01-01
# 20 1980-03-01 2018-12-01

# %% [markdown]
# ## Climatology

# %%
climatology = df_trimmed[df_trimmed['processing_level']=='climatology']
climatology
# Out:
#                                     id            type processing_level  \
# 21  ECMWF_ERA5-Land_NAM_reconstruction  reconstruction      climatology
# 22  ECMWF_ERA5-Land_NAM_reconstruction  reconstruction      climatology
# 23         GovCan_AHCCD_CAN_station-pr      station-pr      climatology
# 24         GovCan_AHCCD_CAN_station-pr      station-pr      climatology
# 25        GovCan_AHCCD_CAN_station-tas     station-tas      climatology
# 26        GovCan_AHCCD_CAN_station-tas     station-tas      climatology
# 27      GovCan_CaSR_NAM_reconstruction  reconstruction      climatology
# 28      GovCan_CaSR_NAM_reconstruction  reconstruction      climatology
# 29      GovCan_RDRS_NAM_reconstruction  reconstruction      climatology
# 30      GovCan_RDRS_NAM_reconstruction  reconstruction      climatology
# 31   PCIC_PCICBlend_CAN_reconstruction  reconstruction      climatology
# 32   PCIC_PCICBlend_CAN_reconstruction  reconstruction      climatology
# 33   USask_EMDNA_OI_NAM_reconstruction  reconstruction      climatology
# 34   USask_EMDNA_OI_NAM_reconstruction  reconstruction      climatology
#
#    institution     source                                           variable  \
# 21       ECMWF  ERA5-Land  (pr_mean_seasonal_clim_std, tg_mean_seasonal_c...
# 22       ECMWF  ERA5-Land  (tg_mean_annual_clim_std, pr_mean_annual_clim_...
# 23      GovCan      AHCCD  (pr_mean_seasonal_clim_std, pr_mean_seasonal_c...
# 24      GovCan      AHCCD  (pr_mean_annual_clim_mean, pr_mean_annual_clim...
# 25      GovCan      AHCCD  (tg_mean_seasonal_clim_std, tg_mean_seasonal_c...
# 26      GovCan      AHCCD  (tg_mean_annual_clim_std, tg_mean_annual_clim_...
# 27      GovCan       CaSR  (tg_mean_seasonal_clim_std, pr_mean_seasonal_c...
# 28      GovCan       CaSR  (tg_mean_annual_clim_std, pr_mean_annual_clim_...
# 29      GovCan       RDRS  (tg_mean_seasonal_clim_std, pr_mean_seasonal_c...
# 30      GovCan       RDRS  (tg_mean_annual_clim_std, pr_mean_annual_clim_...
# 31        PCIC  PCICBlend  (pr_mean_seasonal_clim_std, tg_mean_seasonal_c...
# 32        PCIC  PCICBlend  (tg_mean_annual_clim_std, pr_mean_annual_clim_...
# 33       USask      EMDNA  (pr_mean_seasonal_clim_std, tg_mean_seasonal_c...
# 34       USask      EMDNA  (tg_mean_annual_clim_std, pr_mean_annual_clim_...
#
#    frequency date_start   date_end
# 21       qtr 1980-03-01 2025-03-01
# 22        yr 1980-01-01 2025-01-01
# 23       qtr 1980-03-01 2017-12-01
# 24        yr 1980-01-01 2017-01-01
# 25       qtr 1980-03-01 2023-12-01
# 26        yr 1980-01-01 2023-01-01
# 27       qtr 1980-03-01 2023-12-01
# 28        yr 1980-01-01 2023-01-01
# 29       qtr 1980-03-01 2018-12-01
# 30        yr 1980-01-01 2018-01-01
# 31       qtr 1980-03-01 2012-12-01
# 32        yr 1980-01-01 2012-01-01
# 33       qtr 1980-03-01 2018-12-01
# 34        yr 1980-01-01 2018-01-01

# %% [markdown]
# ## Performance

# %%
statistics = df_trimmed[df_trimmed['processing_level']=='performance']
statistics
# Out:
#                                                id type processing_level  \
# 35  ERA5-Land_Quebec_GovCan_AHCCD_CAN_station-tas  NaN      performance
# 36  PCICBlend_Quebec_GovCan_AHCCD_CAN_station-tas  NaN      performance
# 37       CaSR_Quebec_GovCan_AHCCD_CAN_station-tas  NaN      performance
# 38       RDRS_Quebec_GovCan_AHCCD_CAN_station-tas  NaN      performance
# 39      EMDNA_Quebec_GovCan_AHCCD_CAN_station-tas  NaN      performance
# 40      EMDNA_Quebec_GovCan_AHCCD_CAN_station-tas  NaN      performance
# 41  PCICBlend_Quebec_GovCan_AHCCD_CAN_station-tas  NaN      performance
# 42  ERA5-Land_Quebec_GovCan_AHCCD_CAN_station-tas  NaN      performance
# 43       CaSR_Quebec_GovCan_AHCCD_CAN_station-tas  NaN      performance
# 44       RDRS_Quebec_GovCan_AHCCD_CAN_station-tas  NaN      performance
# 45   ERA5-Land_Quebec_GovCan_AHCCD_CAN_station-pr  NaN      performance
# 46        CaSR_Quebec_GovCan_AHCCD_CAN_station-pr  NaN      performance
# 47       EMDNA_Quebec_GovCan_AHCCD_CAN_station-pr  NaN      performance
# 48        RDRS_Quebec_GovCan_AHCCD_CAN_station-pr  NaN      performance
# 49   PCICBlend_Quebec_GovCan_AHCCD_CAN_station-pr  NaN      performance
# 50        RDRS_Quebec_GovCan_AHCCD_CAN_station-pr  NaN      performance
# 51       EMDNA_Quebec_GovCan_AHCCD_CAN_station-pr  NaN      performance
# 52   ERA5-Land_Quebec_GovCan_AHCCD_CAN_station-pr  NaN      performance
# 53   PCICBlend_Quebec_GovCan_AHCCD_CAN_station-pr  NaN      performance
# 54        CaSR_Quebec_GovCan_AHCCD_CAN_station-pr  NaN      performance
#
#    institution     source                  variable frequency date_start  \
# 35         NaN  ERA5-Land    (tg_mean_annual_rmse,)       NaN        NaT
# 36         NaN  PCICBlend    (tg_mean_annual_rmse,)       NaN        NaT
# 37         NaN       CaSR    (tg_mean_annual_rmse,)       NaN        NaT
# 38         NaN       RDRS    (tg_mean_annual_rmse,)       NaN        NaT
# 39         NaN      EMDNA    (tg_mean_annual_rmse,)       NaN        NaT
# 40         NaN      EMDNA  (tg_mean_seasonal_rmse,)       NaN        NaT
# 41         NaN  PCICBlend  (tg_mean_seasonal_rmse,)       NaN        NaT
# 42         NaN  ERA5-Land  (tg_mean_seasonal_rmse,)       NaN        NaT
# 43         NaN       CaSR  (tg_mean_seasonal_rmse,)       NaN        NaT
# 44         NaN       RDRS  (tg_mean_seasonal_rmse,)       NaN        NaT
# 45         NaN  ERA5-Land    (pr_mean_annual_rmse,)       NaN        NaT
# 46         NaN       CaSR    (pr_mean_annual_rmse,)       NaN        NaT
# 47         NaN      EMDNA    (pr_mean_annual_rmse,)       NaN        NaT
# 48         NaN       RDRS    (pr_mean_annual_rmse,)       NaN        NaT
# 49         NaN  PCICBlend    (pr_mean_annual_rmse,)       NaN        NaT
# 50         NaN       RDRS  (pr_mean_seasonal_rmse,)       NaN        NaT
# 51         NaN      EMDNA  (pr_mean_seasonal_rmse,)       NaN        NaT
# 52         NaN  ERA5-Land  (pr_mean_seasonal_rmse,)       NaN        NaT
# 53         NaN  PCICBlend  (pr_mean_seasonal_rmse,)       NaN        NaT
# 54         NaN       CaSR  (pr_mean_seasonal_rmse,)       NaN        NaT
#
#    date_end
# 35      NaT
# 36      NaT
# 37      NaT
# 38      NaT
# 39      NaT
# 40      NaT
# 41      NaT
# 42      NaT
# 43      NaT
# 44      NaT
# 45      NaT
# 46      NaT
# 47      NaT
# 48      NaT
# 49      NaT
# 50      NaT
# 51      NaT
# 52      NaT
# 53      NaT
# 54      NaT

# %% [markdown]
# ## Checking periods

# %%
ds_dict = pcat.search(processing_level='indicators', frequency=['yr'],source='CaSR').to_dataset_dict()
ds_dict.keys()
# Out:
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'id.domain.processing_level.xrfreq'
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='1' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1/1 00:00&lt;00:00]
#     </div>
# dict_keys(['GovCan_CaSR_NAM_reconstruction.Quebec.indicators.YS-JAN'])

# %%
ds = ds_dict['GovCan_CaSR_NAM_reconstruction.Quebec.indicators.YS-JAN']

# %%
ds.tg_mean_annual.attrs
# Out:
# {'cell_methods': 'time: mean (interval: 1 day) time: mean over days',
#  'description': 'Annual mean of daily mean temperature.',
#  'grid_mapping': 'rotated_pole',
#  'history': "[2025-07-02 16:14:06] tg_mean_annual: indicators_obs.TG_MEAN_ANNUAL(tas=tas) with options check_missing=wmo, missing_options={'nm': 11, 'nc': 5} - xclim version: 0.55.1",
#  'long_name': 'Mean daily mean temperature',
#  'original_variable': 'P_TT_1.5m',
#  'standard_name': 'air_temperature',
#  'units': '°C',
#  'units_metadata': 'temperature: unknown'}
